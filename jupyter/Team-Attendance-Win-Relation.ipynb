# %%
import csv
import numpy
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr
# %matplotlib inline

# %%
# File names
teams_file = "Data//Teams.csv"

path = "Data//Retrosheet//GL"
startyr = 1970
endyr = 2016

# %%
# Indicies
# game logs
teamx, vscorex, hscorex, parkx, attx  = 6, 9, 10, 16, 17

# teams_file
yrx, teamidx, gx, home_gx, wx, lx = 0, 2, 6, 7, 8, 9
team_namex, avg_attx = 40, 42

# %%
def readcsv(fname):
    f = open(fname, 'r')
    reader = csv.reader(f)
    lines = list(reader)
    f.close()
    return lines

# %%
class Team:
    def __init__(self, team, teamid, yr):
        self.name = team
        self.teamid = teamid
        self.year = yr
        self.avg_att = 0
        self.att_std = 0
        self.games = []
    def addGame(self, line):
        self.games.append(line)
    def calcStandardDeviation(self):
        game_att = []
        for g in range(0, len(self.games)):
            game = self.games[g]
            att = int(game[attx])
            game_att.append(att)
        std = numpy.std(game_att)
        self.att_std = std
    def setAvgAtt(self):
        num_games = len(self.games)
        total_att = 0
        for i in range(0, num_games):
            total_att += int(self.games[i][attx])
        self.avg_att = total_att / num_games
    def getAttDeviation(self, game):
        deviation = int(game[attx]) - self.avg_att
        return deviation
    def win(self, game):
        if game[hscorex] > game[vscorex]:
            return True
        else:
            return False

# %%
def build_teamid_ref(lines):
    d = {}
    for line in lines:
        teamid = line[teamidx]
        if teamid not in d:
            d[teamid] = line[team_namex]
    return d

# %%
# builds a dictionary -> {year: {team_name: Team, ...}, ...}
def build_years_dict():
    # create the teamid dictionary for refference
    team_lines = readcsv(teams_file)
    team_ref = build_teamid_ref(team_lines[1:])
    
    years = {}
    for yr in range(startyr, (endyr + 1)):
        # add year to dict and initialize a dict for teams
        years[yr] = {}
        # gather game data for year
        yr_file = path + str(yr) + ".csv"
        games = readcsv(yr_file)
        for game in games:
            # validate data
            if game[attx]:                
                if int(game[attx]) > 0:
                    # check if team is in team dict or not
                    teamid = game[teamx]
                    team_name = team_ref[teamid]
                    if team_name not in years[yr]:
                        years[yr][team_name] = Team(team_name, teamid, yr)
                    # add game data to proper team
                    years[yr][team_name].addGame(game)
                    
    # calculate standard deviations of attendance
    for yr in years:
        for team in years[yr]:
            team = years[yr][team]
            team.calcStandardDeviation()
            team.setAvgAtt()
    
    return years

# %%
# Analyzes game data to see if high attendance number translate to higher team performance
def find_supported_percentages(years):
    for y in years:
        year = years[y]
        highPct = ("", 0)
        lowPct = ("", 101)
    
        for t in year:
            team = year[t]
            supported = 0
            games_analyzed = 0
            for g in range(0, len(team.games)):
                game = team.games[g]
                att_dev = team.getAttDeviation(game)
                # check if high/low attendance translates to win/loss
                if abs(att_dev) > team.att_std:
                    games_analyzed += 1
                    if att_dev > 0 and team.win(game):
                        supported += 1
                    elif att_dev < 0 and not team.win(game):
                        supported += 1
            if games_analyzed > 10:   
                pctSupported = round((supported / games_analyzed) * 100, 2)
                if pctSupported > highPct[1]:
                    highPct = (team.name, pctSupported)
                if pctSupported < lowPct[1]:
                    lowPct = (team.name, pctSupported)
        
        print(str(y) + ":")
        print("Team most positively supported by attendence level:", highPct[0], "at", str(highPct[1]) + "%")
        print("Team most negatively supported by attendence level:", lowPct[0], "at",  str(lowPct[1]) + "%\n")

# %%
years = build_years_dict()

# %%
find_supported_percentages(years)
# Out:
# 1970:
# Team most positively supported by attendence level: Montreal Expos at 61.54%
# Team most negatively supported by attendence level: California Angels at 14.29%
#
# 1971:
# Team most positively supported by attendence level: Philadelphia Quakers at 75.0%
# Team most negatively supported by attendence level: Kansas City Royals at 27.27%
#
# 1972:
# Team most positively supported by attendence level: Oakland Athletics at 66.67%
# Team most negatively supported by attendence level: Chicago White Sox at 31.82%
#
# 1973:
# Team most positively supported by attendence level: Milwaukee Brewers at 73.68%
# Team most negatively supported by attendence level: Minnesota Twins at 20.0%
#
# 1974:
# Team most positively supported by attendence level: Atlanta Braves at 81.82%
# Team most negatively supported by attendence level: Chicago White Sox at 31.82%
#
# 1975:
# Team most positively supported by attendence level: Cincinnati Reds at 69.7%
# Team most negatively supported by attendence level: San Diego Padres at 29.41%
#
# 1976:
# Team most positively supported by attendence level: Chicago White Sox at 72.22%
# Team most negatively supported by attendence level: New York Mets at 28.57%
#
# 1977:
# Team most positively supported by attendence level: Kansas City Royals at 70.97%
# Team most negatively supported by attendence level: Texas Rangers at 20.0%
#
# 1978:
# Team most positively supported by attendence level: Pittsburg Alleghenys at 73.33%
# Team most negatively supported by attendence level: Montreal Expos at 34.78%
#
# 1979:
# Team most positively supported by attendence level: Philadelphia Quakers at 65.22%
# Team most negatively supported by attendence level: Oakland Athletics at 8.33%
#
# 1980:
# Team most positively supported by attendence level: Houston Colt .45's at 61.29%
# Team most negatively supported by attendence level: Chicago White Sox at 8.7%
#
# 1981:
# Team most positively supported by attendence level: Pittsburg Alleghenys at 76.92%
# Team most negatively supported by attendence level: St. Louis Browns at 23.08%
#
# 1982:
# Team most positively supported by attendence level: California Angels at 73.91%
# Team most negatively supported by attendence level: Toronto Blue Jays at 26.09%
#
# 1983:
# Team most positively supported by attendence level: Chicago White Sox at 70.0%
# Team most negatively supported by attendence level: Boston Americans at 24.14%
#
# 1984:
# Team most positively supported by attendence level: Philadelphia Quakers at 70.0%
# Team most negatively supported by attendence level: San Diego Padres at 33.33%
#
# 1985:
# Team most positively supported by attendence level: San Francisco Giants at 80.0%
# Team most negatively supported by attendence level: Minnesota Twins at 13.79%
#
# 1986:
# Team most positively supported by attendence level: Houston Colt .45's at 71.88%
# Team most negatively supported by attendence level: Pittsburg Alleghenys at 29.41%
#
# 1987:
# Team most positively supported by attendence level: Baltimore Orioles at 70.83%
# Team most negatively supported by attendence level: Milwaukee Brewers at 22.22%
#
# 1988:
# Team most positively supported by attendence level: San Diego Padres at 85.71%
# Team most negatively supported by attendence level: Pittsburg Alleghenys at 31.25%
#
# 1989:
# Team most positively supported by attendence level: Cleveland Blues at 78.57%
# Team most negatively supported by attendence level: San Diego Padres at 31.82%
#
# 1990:
# Team most positively supported by attendence level: Philadelphia Quakers at 70.37%
# Team most negatively supported by attendence level: California Angels at 31.82%
#
# 1991:
# Team most positively supported by attendence level: Chicago White Stockings at 68.75%
# Team most negatively supported by attendence level: New York Highlanders at 33.33%
#
# 1992:
# Team most positively supported by attendence level: California Angels at 66.67%
# Team most negatively supported by attendence level: Houston Colt .45's at 22.86%
#
# 1993:
# Team most positively supported by attendence level: Boston Americans at 85.71%
# Team most negatively supported by attendence level: Cleveland Blues at 25.0%
#
# 1994:
# Team most positively supported by attendence level: San Francisco Giants at 72.73%
# Team most negatively supported by attendence level: Minnesota Twins at 23.81%
#
# 1995:
# Team most positively supported by attendence level: San Francisco Giants at 82.35%
# Team most negatively supported by attendence level: Chicago White Sox at 21.05%
#
# 1996:
# Team most positively supported by attendence level: California Angels at 61.11%
# Team most negatively supported by attendence level: Toronto Blue Jays at 34.78%
#
# 1997:
# Team most positively supported by attendence level: New York Mets at 69.57%
# Team most negatively supported by attendence level: Toronto Blue Jays at 22.73%
#
# 1998:
# Team most positively supported by attendence level: Chicago White Sox at 83.33%
# Team most negatively supported by attendence level: Chicago White Stockings at 27.78%
#
# 1999:
# Team most positively supported by attendence level: Chicago White Sox at 61.54%
# Team most negatively supported by attendence level: Chicago White Stockings at 23.08%
#
# 2000:
# Team most positively supported by attendence level: Chicago White Sox at 65.38%
# Team most negatively supported by attendence level: Kansas City Royals at 25.93%
#
# 2001:
# Team most positively supported by attendence level: Arizona Diamondbacks at 65.38%
# Team most negatively supported by attendence level: Chicago White Stockings at 31.25%
#
# 2002:
# Team most positively supported by attendence level: Florida Marlins at 66.67%
# Team most negatively supported by attendence level: Los Angeles Dodgers at 28.12%
#
# 2003:
# Team most positively supported by attendence level: Florida Marlins at 70.59%
# Team most negatively supported by attendence level: Boston Americans at 7.69%
#
# 2004:
# Team most positively supported by attendence level: Boston Americans at 69.57%
# Team most negatively supported by attendence level: New York Highlanders at 23.08%
#
# 2005:
# Team most positively supported by attendence level: Tampa Bay Devil Rays at 75.0%
# Team most negatively supported by attendence level: Chicago White Sox at 30.56%
#
# 2006:
# Team most positively supported by attendence level: Pittsburg Alleghenys at 64.71%
# Team most negatively supported by attendence level: Arizona Diamondbacks at 26.09%
#
# 2007:
# Team most positively supported by attendence level: Cincinnati Reds at 62.07%
# Team most negatively supported by attendence level: Milwaukee Brewers at 21.05%
#
# 2008:
# Team most positively supported by attendence level: Houston Colt .45's at 61.54%
# Team most negatively supported by attendence level: New York Mets at 33.33%
#
# 2009:
# Team most positively supported by attendence level: Chicago White Sox at 62.96%
# Team most negatively supported by attendence level: Oakland Athletics at 29.17%
#
# 2010:
# Team most positively supported by attendence level: Chicago White Sox at 68.97%
# Team most negatively supported by attendence level: Philadelphia Quakers at 33.33%
#
# 2011:
# Team most positively supported by attendence level: Chicago White Sox at 71.43%
# Team most negatively supported by attendence level: Toronto Blue Jays at 21.05%
#
# 2012:
# Team most positively supported by attendence level: Chicago White Sox at 65.38%
# Team most negatively supported by attendence level: Philadelphia Quakers at 25.0%
#
# 2013:
# Team most positively supported by attendence level: Anaheim Angels at 69.23%
# Team most negatively supported by attendence level: Washington Senators at 30.0%
#
# 2014:
# Team most positively supported by attendence level: Seattle Mariners at 63.33%
# Team most negatively supported by attendence level: Colorado Rockies at 24.14%
#
# 2015:
# Team most positively supported by attendence level: Pittsburg Alleghenys at 68.0%
# Team most negatively supported by attendence level: New York Mets at 37.14%
#
# 2016:
# Team most positively supported by attendence level: Colorado Rockies at 68.97%
# Team most negatively supported by attendence level: Chicago White Stockings at 23.08%
