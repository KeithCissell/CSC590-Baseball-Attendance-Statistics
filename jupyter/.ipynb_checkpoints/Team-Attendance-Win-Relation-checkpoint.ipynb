# %%
import csv
import numpy
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr
# %matplotlib inline

# %%
# File names
teams_file = "Data//Teams.csv"

path = "Data//Retrosheet//GL"
startyr = 1970
endyr = 2016

# %%
# Indicies
# game logs
teamx, vscorex, hscorex, parkx, attx  = 6, 9, 10, 16, 17

# teams_file
yrx, teamidx, gx, home_gx, wx, lx = 0, 2, 6, 7, 8, 9
team_namex, avg_attx = 40, 42

# %%
def readcsv(fname):
    f = open(fname, 'r')
    reader = csv.reader(f)
    lines = list(reader)
    f.close()
    return lines

# %%
class Team:
    def __init__(self, team, teamid, yr):
        self.name = team
        self.teamid = teamid
        self.year = yr
        self.avg_att = 0
        self.att_std = 0
        self.games = []
    def addGame(self, line):
        self.games.append(line)
    def calcStandardDeviation(self):
        game_att = []
        for g in range(0, len(self.games)):
            game = self.games[g]
            att = int(game[attx])
            game_att.append(att)
        std = numpy.std(game_att)
        self.att_std = std
    def setAvgAtt(self):
        num_games = len(self.games)
        total_att = 0
        for i in range(0, num_games):
            total_att += int(self.games[i][attx])
        self.avg_att = total_att / num_games
    def getAttDeviation(self, game):
        deviation = int(game[attx]) - self.avg_att
        return deviation
    def win(self, game):
        if game[hscorex] > game[vscorex]:
            return True
        else:
            return False

# %%
def build_teamid_ref(lines):
    d = {}
    sortedLines = sorted(lines, key=lambda y: y[yrx], reverse=True)
    for line in sortedLines:
        teamid = line[teamidx]
        if teamid not in d:
            d[teamid] = line[team_namex]
    return d

# %%
# builds a dictionary -> {year: {team_name: Team, ...}, ...}
def build_years_dict():
    # create the teamid dictionary for refference
    team_lines = readcsv(teams_file)
    team_ref = build_teamid_ref(team_lines[1:])
    
    years = {}
    for yr in range(startyr, (endyr + 1)):
        # add year to dict and initialize a dict for teams
        years[yr] = {}
        # gather game data for year
        yr_file = path + str(yr) + ".csv"
        games = readcsv(yr_file)
        for game in games:
            # validate data
            if game[attx]:                
                if int(game[attx]) > 0:
                    # check if team is in team dict or not
                    teamid = game[teamx]
                    team_name = team_ref[teamid]
                    if team_name not in years[yr]:
                        years[yr][team_name] = Team(team_name, teamid, yr)
                    # add game data to proper team
                    years[yr][team_name].addGame(game)
                    
    # calculate standard deviations of attendance
    for yr in years:
        for team in years[yr]:
            team = years[yr][team]
            team.calcStandardDeviation()
            team.setAvgAtt()
    
    return years

# %%
# Analyzes game data to see if high attendance number translate to higher team performance
def find_supported_percentages(years):
    sortedYears = sorted(years.keys(), reverse=True)
    for y in sortedYears:
        year = years[y]
        highPct = ("", 0)
        lowPct = ("", 101)
    
        for t in year:
            team = year[t]
            supported = 0
            games_analyzed = 0
            for g in range(0, len(team.games)):
                game = team.games[g]
                att_dev = team.getAttDeviation(game)
                # check if high/low attendance translates to win/loss
                if abs(att_dev) > team.att_std:
                    games_analyzed += 1
                    if att_dev > 0 and team.win(game):
                        supported += 1
                    elif att_dev < 0 and not team.win(game):
                        supported += 1
            if games_analyzed > 10:
                preNormalized = (supported / games_analyzed) * 100
                pctSupported = round(((preNormalized - 50) * 2), 2)
                if pctSupported > highPct[1]:
                    highPct = (team.name, pctSupported)
                if pctSupported < lowPct[1]:
                    lowPct = (team.name, pctSupported)
        
        print(str(y) + ":")
        print("Team most positively effected by attendence level:", highPct[0], "at", str(highPct[1]) + "%")
        print("Team most negatively effected by attendence level:", lowPct[0], "at",  str(lowPct[1]) + "%\n")

# %%
years = build_years_dict()

# %%
find_supported_percentages(years)
# Out:
# 2016:
# Team most positively effected by attendence level: Colorado Rockies at 37.93%
# Team most negatively effected by attendence level: Chicago Cubs at -53.85%
#
# 2015:
# Team most positively effected by attendence level: Pittsburgh Pirates at 36.0%
# Team most negatively effected by attendence level: New York Mets at -25.71%
#
# 2014:
# Team most positively effected by attendence level: Seattle Mariners at 26.67%
# Team most negatively effected by attendence level: Colorado Rockies at -51.72%
#
# 2013:
# Team most positively effected by attendence level: Anaheim Angels at 38.46%
# Team most negatively effected by attendence level: Washington Nationals at -40.0%
#
# 2012:
# Team most positively effected by attendence level: Chicago White Sox at 30.77%
# Team most negatively effected by attendence level: Philadelphia Phillies at -50.0%
#
# 2011:
# Team most positively effected by attendence level: Chicago White Sox at 42.86%
# Team most negatively effected by attendence level: Toronto Blue Jays at -57.89%
#
# 2010:
# Team most positively effected by attendence level: Chicago White Sox at 37.93%
# Team most negatively effected by attendence level: Philadelphia Phillies at -33.33%
#
# 2009:
# Team most positively effected by attendence level: Chicago White Sox at 25.93%
# Team most negatively effected by attendence level: Oakland Athletics at -41.67%
#
# 2008:
# Team most positively effected by attendence level: Houston Astros at 23.08%
# Team most negatively effected by attendence level: New York Mets at -33.33%
#
# 2007:
# Team most positively effected by attendence level: Cincinnati Reds at 24.14%
# Team most negatively effected by attendence level: Milwaukee Brewers at -57.89%
#
# 2006:
# Team most positively effected by attendence level: Pittsburgh Pirates at 29.41%
# Team most negatively effected by attendence level: Arizona Diamondbacks at -47.83%
#
# 2005:
# Team most positively effected by attendence level: Tampa Bay Rays at 50.0%
# Team most negatively effected by attendence level: Chicago White Sox at -38.89%
#
# 2004:
# Team most positively effected by attendence level: Boston Red Sox at 39.13%
# Team most negatively effected by attendence level: New York Yankees at -53.85%
#
# 2003:
# Team most positively effected by attendence level: Florida Marlins at 41.18%
# Team most negatively effected by attendence level: Boston Red Sox at -84.62%
#
# 2002:
# Team most positively effected by attendence level: Florida Marlins at 33.33%
# Team most negatively effected by attendence level: Los Angeles Dodgers at -43.75%
#
# 2001:
# Team most positively effected by attendence level: Arizona Diamondbacks at 30.77%
# Team most negatively effected by attendence level: Boston Red Sox at -37.5%
#
# 2000:
# Team most positively effected by attendence level: Chicago White Sox at 30.77%
# Team most negatively effected by attendence level: Kansas City Royals at -48.15%
#
# 1999:
# Team most positively effected by attendence level: Chicago White Sox at 23.08%
# Team most negatively effected by attendence level: Chicago Cubs at -53.85%
#
# 1998:
# Team most positively effected by attendence level: Chicago White Sox at 66.67%
# Team most negatively effected by attendence level: Chicago Cubs at -44.44%
#
# 1997:
# Team most positively effected by attendence level: New York Mets at 39.13%
# Team most negatively effected by attendence level: Toronto Blue Jays at -54.55%
#
# 1996:
# Team most positively effected by attendence level: California Angels at 22.22%
# Team most negatively effected by attendence level: Toronto Blue Jays at -30.43%
#
# 1995:
# Team most positively effected by attendence level: San Francisco Giants at 64.71%
# Team most negatively effected by attendence level: Chicago White Sox at -57.89%
#
# 1994:
# Team most positively effected by attendence level: San Francisco Giants at 45.45%
# Team most negatively effected by attendence level: Minnesota Twins at -52.38%
#
# 1993:
# Team most positively effected by attendence level: Boston Red Sox at 71.43%
# Team most negatively effected by attendence level: Cleveland Indians at -50.0%
#
# 1992:
# Team most positively effected by attendence level: California Angels at 33.33%
# Team most negatively effected by attendence level: Houston Astros at -54.29%
#
# 1991:
# Team most positively effected by attendence level: Chicago Cubs at 37.5%
# Team most negatively effected by attendence level: New York Yankees at -33.33%
#
# 1990:
# Team most positively effected by attendence level: Philadelphia Phillies at 40.74%
# Team most negatively effected by attendence level: California Angels at -36.36%
#
# 1989:
# Team most positively effected by attendence level: Cleveland Indians at 57.14%
# Team most negatively effected by attendence level: San Diego Padres at -36.36%
#
# 1988:
# Team most positively effected by attendence level: San Diego Padres at 71.43%
# Team most negatively effected by attendence level: Pittsburgh Pirates at -37.5%
#
# 1987:
# Team most positively effected by attendence level: Baltimore Orioles at 41.67%
# Team most negatively effected by attendence level: Milwaukee Brewers at -55.56%
#
# 1986:
# Team most positively effected by attendence level: Houston Astros at 43.75%
# Team most negatively effected by attendence level: Pittsburgh Pirates at -41.18%
#
# 1985:
# Team most positively effected by attendence level: San Francisco Giants at 60.0%
# Team most negatively effected by attendence level: Minnesota Twins at -72.41%
#
# 1984:
# Team most positively effected by attendence level: Philadelphia Phillies at 40.0%
# Team most negatively effected by attendence level: Texas Rangers at -33.33%
#
# 1983:
# Team most positively effected by attendence level: Chicago White Sox at 40.0%
# Team most negatively effected by attendence level: Boston Red Sox at -51.72%
#
# 1982:
# Team most positively effected by attendence level: California Angels at 47.83%
# Team most negatively effected by attendence level: Toronto Blue Jays at -47.83%
#
# 1981:
# Team most positively effected by attendence level: Pittsburgh Pirates at 53.85%
# Team most negatively effected by attendence level: St. Louis Cardinals at -53.85%
#
# 1980:
# Team most positively effected by attendence level: Houston Astros at 22.58%
# Team most negatively effected by attendence level: Chicago White Sox at -82.61%
#
# 1979:
# Team most positively effected by attendence level: Philadelphia Phillies at 30.43%
# Team most negatively effected by attendence level: Oakland Athletics at -83.33%
#
# 1978:
# Team most positively effected by attendence level: Pittsburgh Pirates at 46.67%
# Team most negatively effected by attendence level: Montreal Expos at -30.43%
#
# 1977:
# Team most positively effected by attendence level: Kansas City Royals at 41.94%
# Team most negatively effected by attendence level: Texas Rangers at -60.0%
#
# 1976:
# Team most positively effected by attendence level: Chicago White Sox at 44.44%
# Team most negatively effected by attendence level: New York Mets at -42.86%
#
# 1975:
# Team most positively effected by attendence level: Cincinnati Reds at 39.39%
# Team most negatively effected by attendence level: San Diego Padres at -41.18%
#
# 1974:
# Team most positively effected by attendence level: Atlanta Braves at 63.64%
# Team most negatively effected by attendence level: Chicago White Sox at -36.36%
#
# 1973:
# Team most positively effected by attendence level: Milwaukee Brewers at 47.37%
# Team most negatively effected by attendence level: Minnesota Twins at -60.0%
#
# 1972:
# Team most positively effected by attendence level: Oakland Athletics at 33.33%
# Team most negatively effected by attendence level: Chicago White Sox at -36.36%
#
# 1971:
# Team most positively effected by attendence level: Philadelphia Phillies at 50.0%
# Team most negatively effected by attendence level: Kansas City Royals at -45.45%
#
# 1970:
# Team most positively effected by attendence level: Montreal Expos at 23.08%
# Team most negatively effected by attendence level: California Angels at -71.43%
